# %%
import matplotlib.pyplot as plt
from onhm import Onhm
import numpy as np
from pymt.models import PRMSSurface
from pathlib import Path
# Out:
# ➡ models: PRMSSurface, PRMSSoil

# %%
wght = '../../onhm-fetcher-parser/Data/weights.csv'
run_dir = '../../bmi-test-projects/prms/pipestem'
config_file = 'control.default'
print(Path(run_dir).exists())
print((Path(run_dir) / config_file).exists())

m = PRMSSurface()
print(m.name)
m.name
# Out:
# True
# True
# prms6-surface-BMI
# 'prms6-surface-BMI'

# %%
m.initialize(config_file, run_dir)
m.get_value('nowtime')
m.get_value('nhm_id')
# Out:
# array([57874, 57875, 57878, 57881, 57868, 57873, 57879, 57880, 57882,
#        57883, 57869, 57870, 57864, 57865], dtype=int32)

# %%
data = Onhm("2019-03-14", end_date="2019-03-24", map=True, hru_id=m.get_value('nhm_id'), wght_file=wght)

# %%
data.tmin
# Out:
# <xarray.DataArray (day: 11, hru_id: 14)>
# array([[ -9.54934841,  -9.86419864,  -9.46136844,  -9.54632678,
#          -9.51039872,  -9.53448029,  -9.62040139,  -9.66450702,
#          -9.82549088,  -9.76160127,  -9.68190805,  -9.61981582,
#          -9.05765642,  -9.35971147],
#        [-16.95520658, -17.12877433, -16.144958  , -16.24607613,
#         -17.24629532, -17.04771923, -16.59953754, -16.78183104,
#         -17.11483779, -16.97473885, -17.12580792, -16.96321362,
#         -16.90465808, -17.06543361],
#        [-17.26591025, -17.23712735, -16.66426274, -16.6979819 ,
#         -17.68670055, -17.54179871, -16.98922452, -17.09234105,
#         -17.24669463, -17.18408651, -17.42987253, -17.19339676,
#         -17.57890761, -17.48219626],
#        [-12.13084364, -12.66842551, -12.08982473, -12.10404866,
#         -11.92890113, -11.90823673, -12.22401127, -12.26557253,
#         -12.53169948, -12.40658352, -12.27014644, -12.13304165,
#         -10.85265627, -11.70220911],
#        [-10.89003528, -11.64686658, -10.66275888, -10.71556313,
#         -10.89224222, -11.00678611, -10.95949834, -11.05507967,
#         -11.46666799, -11.28443157, -11.27860448, -11.276414  ,
#         -10.23243742, -10.66113649],
#        [ -7.45677643,  -7.28934101,  -7.46339452,  -7.57029159,
#          -7.35008205,  -7.10329631,  -7.53540855,  -7.55803461,
#          -7.50943635,  -7.55541051,  -7.3003708 ,  -7.10660324,
#          -6.72529679,  -7.20164654],
#        [ -4.68942735,  -4.87883425,  -4.59442657,  -4.53578904,
#          -4.65456721,  -4.59441246,  -4.69175445,  -4.66556643,
#          -4.86994037,  -4.70460567,  -4.81204278,  -4.71982193,
#          -4.15599706,  -4.63216481],
#        [ -9.2069852 , -10.33582747,  -9.15663661,  -9.21691074,
#          -8.99218326,  -9.20534149,  -9.57600594,  -9.74623358,
#         -10.18722792, -10.00608597,  -9.74330947,  -9.73301724,
#          -7.70628821,  -8.53898548],
#        [ -9.13866956, -10.10262612,  -9.11143426,  -9.12515653,
#          -9.0251941 ,  -9.31551539,  -9.34878943,  -9.46579605,
#          -9.77335454,  -9.59769995,  -9.61976165,  -9.67642517,
#          -8.33798728,  -8.77443203],
#        [ -5.06712926,  -4.00377795,  -4.74669633,  -4.60478053,
#          -5.64233985,  -5.17772867,  -4.77343321,  -4.67900203,
#          -4.32415932,  -4.38749474,  -4.82277773,  -4.66695835,
#          -6.57290498,  -5.94564028],
#        [-11.57363895, -11.88159139, -10.97320765, -10.86096441,
#         -11.78556501, -11.70979185, -11.49473733, -11.64704506,
#         -11.84463785, -11.66824722, -11.89128779, -11.70660934,
#         -11.40083145, -11.54861112]])
# Coordinates:
#   * day      (day) datetime64[ns] 2019-03-14 2019-03-15 ... 2019-03-24
#   * hru_id   (hru_id) int32 57874 57875 57878 57881 ... 57869 57870 57864 57865

# %%
plt.imshow(data.tmin.values[:, :])
